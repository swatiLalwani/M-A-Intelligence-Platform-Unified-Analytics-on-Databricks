# %% [markdown]
# **Import Required Libraries**

# %%
from pyspark.sql import functions as F
from delta.tables import DeltaTable
from pyspark.sql.window import Window

# %% [markdown]
# **Load Project Utilities & Initialize Notebook Widgets**

# %%
# %run /Workspace/Users/swatilalwani342@gmail.com/Consolidated_pipeline/1_setup/utilities

# %%
print(bronze_schema, silver_schema, gold_schema)
# Out:
# bronze silver gold

# %%
dbutils.widgets.text("catalog", "fmcg", "Catalog")
dbutils.widgets.text("data_source", "gross_price", "Data Source")

catalog = dbutils.widgets.get("catalog")
data_source = dbutils.widgets.get("data_source")

base_path = f's3://sportsbar-asap/{data_source}/*.csv'
print(base_path)
# Out:
# s3://sportsbar-asap/gross_price/*.csv

# %% [markdown]
# ## Bronze

# %%
df = (
    spark.read.format("csv")
        .option("header", True)
        .option("inferSchema", True)
        .load(base_path)
        .withColumn("read_timestamp", F.current_timestamp())
        .select("*", "_metadata.file_name", "_metadata.file_size")
)

# %%
# print check data type
df.printSchema()
# Out:
# root
#  |-- product_id: integer (nullable = true)
#  |-- month: string (nullable = true)
#  |-- gross_price: string (nullable = true)
#  |-- read_timestamp: timestamp (nullable = false)
#  |-- file_name: string (nullable = false)
#  |-- file_size: long (nullable = false)

# %%
display(df.limit(10))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>product_id</th><th>month</th><th>gross_price</th><th>read_timestamp</th><th>file_name</th><th>file_size</th></tr></thead><tbody><tr><td>25891101</td><td>2025/07/01</td><td>-84</td><td>2026-01-15T22:27:58.390Z</td><td>gross_price.csv</td><td>2741</td></tr><tr><td>25891101</td><td>01/08/2025</td><td>unknown</td><td>2026-01-15T22:27:58.390Z</td><td>gross_price.csv</td><td>2741</td></tr><tr><td>25891101</td><td>2025/09/01</td><td>84</td><td>2026-01-15T22:27:58.390Z</td><td>gross_price.csv</td><td>2741</td></tr><tr><td>25891101</td><td>2025-10-01</td><td>83</td><td>2026-01-15T22:27:58.390Z</td><td>gross_price.csv</td><td>2741</td></tr><tr><td>25891101</td><td>2025-11-01</td><td>83</td><td>2026-01-15T22:27:58.390Z</td><td>gross_price.csv</td><td>2741</td></tr><tr><td>88888888</td><td>2025-12-01</td><td>-83</td><td>2026-01-15T22:27:58.390Z</td><td>gross_price.csv</td><td>2741</td></tr><tr><td>25891102</td><td>2025-07-01</td><td>68</td><td>2026-01-15T22:27:58.390Z</td><td>gross_price.csv</td><td>2741</td></tr><tr><td>25891102</td><td>2025-08-01</td><td>68</td><td>2026-01-15T22:27:58.390Z</td><td>gross_price.csv</td><td>2741</td></tr><tr><td>25891102</td><td>2025-09-01</td><td>68</td><td>2026-01-15T22:27:58.390Z</td><td>gross_price.csv</td><td>2741</td></tr><tr><td>25891102</td><td>2025-10-01</td><td>69</td><td>2026-01-15T22:27:58.390Z</td><td>gross_price.csv</td><td>2741</td></tr></tbody></table></div>

# %%
df.write\
 .format("delta") \
 .option("delta.enableChangeDataFeed", "true") \
 .mode("overwrite") \
 .saveAsTable(f"{catalog}.{bronze_schema}.{data_source}")

# %% [markdown]
# ## Silver

# %%
df_bronze = spark.sql(f"SELECT * FROM {catalog}.{bronze_schema}.{data_source};")
df_bronze.show(10)
# Out:
# +----------+----------+-----------+--------------------+---------------+---------+
# |product_id|     month|gross_price|      read_timestamp|      file_name|file_size|
# +----------+----------+-----------+--------------------+---------------+---------+
# |  25891101|2025/07/01|        -84|2026-01-15 22:28:...|gross_price.csv|     2741|
# |  25891101|01/08/2025|    unknown|2026-01-15 22:28:...|gross_price.csv|     2741|
# |  25891101|2025/09/01|         84|2026-01-15 22:28:...|gross_price.csv|     2741|
# |  25891101|2025-10-01|         83|2026-01-15 22:28:...|gross_price.csv|     2741|
# |  25891101|2025-11-01|         83|2026-01-15 22:28:...|gross_price.csv|     2741|
# |  88888888|2025-12-01|        -83|2026-01-15 22:28:...|gross_price.csv|     2741|
# |  25891102|2025-07-01|         68|2026-01-15 22:28:...|gross_price.csv|     2741|
# |  25891102|2025-08-01|         68|2026-01-15 22:28:...|gross_price.csv|     2741|
# |  25891102|2025-09-01|         68|2026-01-15 22:28:...|gross_price.csv|     2741|
# |  25891102|2025-10-01|         69|2026-01-15 22:28:...|gross_price.csv|     2741|
# +----------+----------+-----------+--------------------+---------------+---------+
# only showing top 10 rows

# %%
df_silver = spark.table(
    "fmcg.bronze.gross_price"
)
display(df_silver)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>product_id</th><th>month</th><th>gross_price</th><th>read_timestamp</th><th>file_name</th><th>file_size</th></tr></thead><tbody><tr><td>25891101</td><td>2025/07/01</td><td>-84</td><td>2026-01-15T22:28:21.459Z</td><td>gross_price.csv</td><td>2741</td></tr><tr><td>25891101</td><td>01/08/2025</td><td>unknown</td><td>2026-01-15T22:28:21.459Z</td><td>gross_price.csv</td><td>2741</td></tr><tr><td>25891101</td><td>2025/09/01</td><td>84</td><td>2026-01-15T22:28:21.459Z</td><td>gross_price.csv</td><td>2741</td></tr><tr><td>25891101</td><td>2025-10-01</td><td>83</td><td>2026-01-15T22:28:21.459Z</td><td>gross_price.csv</td><td>2741</td></tr><tr><td>25891101</td><td>2025-11-01</td><td>83</td><td>2026-01-15T22:28:21.459Z</td><td>gross_price.csv</td><td>2741</td></tr><tr><td>88888888</td><td>2025-12-01</td><td>-83</td><td>2026-01-15T22:28:21.459Z</td><td>gross_price.csv</td><td>2741</td></tr><tr><td>25891102</td><td>2025-07-01</td><td>68</td><td>2026-01-15T22:28:21.459Z</td><td>gross_price.csv</td><td>2741</td></tr><tr><td>25891102</td><td>2025-08-01</td><td>68</td><td>2026-01-15T22:28:21.459Z</td><td>gross_price.csv</td><td>2741</td></tr><tr><td>25891102</td><td>2025-09-01</td><td>68</td><td>2026-01-15T22:28:21.459Z</td><td>gross_price.csv</td><td>2741</td></tr><tr><td>25891102</td><td>2025-10-01</td><td>69</td><td>2026-01-15T22:28:21.459Z</td><td>gross_price.csv</td><td>2741</td></tr><tr><td>25891102</td><td>2025-11-01</td><td>69</td><td>2026-01-15T22:28:21.459Z</td><td>gross_price.csv</td><td>2741</td></tr><tr><td>25891102</td><td>2025-12-01</td><td>69</td><td>2026-01-15T22:28:21.459Z</td><td>gross_price.csv</td><td>2741</td></tr><tr><td>25891103</td><td>2025/07/01</td><td>85</td><td>2026-01-15T22:28:21.459Z</td><td>gross_price.csv</td><td>2741</td></tr><tr><td>25891103</td><td>01/08/2025</td><td>85</td><td>2026-01-15T22:28:21.459Z</td><td>gross_price.csv</td><td>2741</td></tr><tr><td>25891103</td><td>2025/09/01</td><td>85</td><td>2026-01-15T22:28:21.459Z</td><td>gross_price.csv</td><td>2741</td></tr><tr><td>25891103</td><td>2025-10-01</td><td>not_available</td><td>2026-01-15T22:28:21.459Z</td><td>gross_price.csv</td><td>2741</td></tr><tr><td>25891103</td><td>2025/11/01</td><td>86</td><td>2026-01-15T22:28:21.459Z</td><td>gross_price.csv</td><td>2741</td></tr><tr><td>25891103</td><td>2025-12-01</td><td>86</td><td>2026-01-15T22:28:21.459Z</td><td>gross_price.csv</td><td>2741</td></tr><tr><td>25891201</td><td>2025-07-01</td><td>108</td><td>2026-01-15T22:28:21.459Z</td><td>gross_price.csv</td><td>2741</td></tr><tr><td>25891201</td><td>2025/08/01</td><td>108</td><td>2026-01-15T22:28:21.459Z</td><td>gross_price.csv</td><td>2741</td></tr><tr><td>25891201</td><td>2025-09-01</td><td>108</td><td>2026-01-15T22:28:21.459Z</td><td>gross_price.csv</td><td>2741</td></tr><tr><td>99999999</td><td>2025-10-01</td><td>108</td><td>2026-01-15T22:28:21.459Z</td><td>gross_price.csv</td><td>2741</td></tr><tr><td>25891201</td><td>2025-11-01</td><td>108</td><td>2026-01-15T22:28:21.459Z</td><td>gross_price.csv</td><td>2741</td></tr><tr><td>25891201</td><td>2025-12-01</td><td>108</td><td>2026-01-15T22:28:21.459Z</td><td>gross_price.csv</td><td>2741</td></tr><tr><td>25891202</td><td>2025-07-01</td><td>94</td><td>2026-01-15T22:28:21.459Z</td><td>gross_price.csv</td><td>2741</td></tr><tr><td>25891202</td><td>2025/08/01</td><td>94</td><td>2026-01-15T22:28:21.459Z</td><td>gross_price.csv</td><td>2741</td></tr><tr><td>25891202</td><td>01-09-2025</td><td>94</td><td>2026-01-15T22:28:21.459Z</td><td>gross_price.csv</td><td>2741</td></tr><tr><td>25891202</td><td>2025/10/01</td><td>100</td><td>2026-01-15T22:28:21.459Z</td><td>gross_price.csv</td><td>2741</td></tr><tr><td>25891202</td><td>2025-11-01</td><td>unknown</td><td>2026-01-15T22:28:21.459Z</td><td>gross_price.csv</td><td>2741</td></tr><tr><td>88888888</td><td>2025-12-01</td><td>100</td><td>2026-01-15T22 ...

# %% [markdown]
# **Transformations**

# %% [markdown]
# 1. Normalize Month Field

# %%
df_bronze.select('month').distinct().show()
# Out:
# +----------+
# |     month|
# +----------+
# |2025/07/01|
# |01/08/2025|
# |2025/09/01|
# |2025-10-01|
# |2025-11-01|
# |2025-12-01|
# |2025-07-01|
# |2025-08-01|
# |2025-09-01|
# |2025/11/01|
# |2025/08/01|
# |01-09-2025|
# |2025/10/01|
# |01/12/2025|
# |01/09/2025|
# |01-12-2025|
# |01-08-2025|
# |01/10/2025|
# +----------+

# %%
# 1️. Parse `month` from multiple possible formats
date_formats = ["yyyy/MM/dd", "dd/MM/yyyy", "yyyy-MM-dd", "dd-MM-yyyy"]

df_silver = df_bronze.withColumn(
    "month",
    F.coalesce(
        F.try_to_date(F.col("month"), "yyyy/MM/dd"),
        F.try_to_date(F.col("month"), "dd/MM/yyyy"),
        F.try_to_date(F.col("month"), "yyyy-MM-dd"),
        F.try_to_date(F.col("month"), "dd-MM-yyyy")
    )
)

# %%
df_silver.select('month').distinct().show()
# Out:
# +----------+
# |     month|
# +----------+
# |2025-07-01|
# |2025-08-01|
# |2025-09-01|
# |2025-10-01|
# |2025-11-01|
# |2025-12-01|
# +----------+

# %%
df_silver.show(10)
# Out:
# +----------+----------+-----------+--------------------+---------------+---------+
# |product_id|     month|gross_price|      read_timestamp|      file_name|file_size|
# +----------+----------+-----------+--------------------+---------------+---------+
# |  25891101|2025-07-01|        -84|2026-01-15 22:28:...|gross_price.csv|     2741|
# |  25891101|2025-08-01|    unknown|2026-01-15 22:28:...|gross_price.csv|     2741|
# |  25891101|2025-09-01|         84|2026-01-15 22:28:...|gross_price.csv|     2741|
# |  25891101|2025-10-01|         83|2026-01-15 22:28:...|gross_price.csv|     2741|
# |  25891101|2025-11-01|         83|2026-01-15 22:28:...|gross_price.csv|     2741|
# |  88888888|2025-12-01|        -83|2026-01-15 22:28:...|gross_price.csv|     2741|
# |  25891102|2025-07-01|         68|2026-01-15 22:28:...|gross_price.csv|     2741|
# |  25891102|2025-08-01|         68|2026-01-15 22:28:...|gross_price.csv|     2741|
# |  25891102|2025-09-01|         68|2026-01-15 22:28:...|gross_price.csv|     2741|
# |  25891102|2025-10-01|         69|2026-01-15 22:28:...|gross_price.csv|     2741|
# +----------+----------+-----------+--------------------+---------------+---------+
# only showing top 10 rows

# %% [markdown]
# - 2: Handling `gross_price`

# %%
# We are validating the gross_price column, converting only valid numeric values to double, fixing negative prices by making them positive, and replacing all non-numeric values with 0


df_silver = df_silver.withColumn(
    "gross_price",
    F.when(F.col("gross_price").rlike(r'^-?\d+(\.\d+)?$'), 
           F.when(F.col("gross_price").cast("double") < 0, -1 * F.col("gross_price").cast("double"))
            .otherwise(F.col("gross_price").cast("double")))
    .otherwise(0)
)

# %%
df_silver.show(10)
# Out:
# +----------+----------+-----------+--------------------+---------------+---------+
# |product_id|     month|gross_price|      read_timestamp|      file_name|file_size|
# +----------+----------+-----------+--------------------+---------------+---------+
# |  25891101|2025-07-01|       84.0|2026-01-15 22:28:...|gross_price.csv|     2741|
# |  25891101|2025-08-01|        0.0|2026-01-15 22:28:...|gross_price.csv|     2741|
# |  25891101|2025-09-01|       84.0|2026-01-15 22:28:...|gross_price.csv|     2741|
# |  25891101|2025-10-01|       83.0|2026-01-15 22:28:...|gross_price.csv|     2741|
# |  25891101|2025-11-01|       83.0|2026-01-15 22:28:...|gross_price.csv|     2741|
# |  88888888|2025-12-01|       83.0|2026-01-15 22:28:...|gross_price.csv|     2741|
# |  25891102|2025-07-01|       68.0|2026-01-15 22:28:...|gross_price.csv|     2741|
# |  25891102|2025-08-01|       68.0|2026-01-15 22:28:...|gross_price.csv|     2741|
# |  25891102|2025-09-01|       68.0|2026-01-15 22:28:...|gross_price.csv|     2741|
# |  25891102|2025-10-01|       69.0|2026-01-15 22:28:...|gross_price.csv|     2741|
# +----------+----------+-----------+--------------------+---------------+---------+
# only showing top 10 rows

# %%
# We enrich the silver dataset by performing an inner join with the products table to fetch the correct product_code for each product_id.

df_products = spark.table("fmcg.silver.products") 
df_joined = df_silver.join(df_products.select("product_id", "product_code"), on="product_id", how="inner")
df_joined = df_joined.select("product_id", "product_code", "month", "gross_price", "read_timestamp", "file_name", "file_size")

df_joined.show(5)
# Out:
# +----------+--------------------+----------+-----------+--------------------+---------------+---------+
# |product_id|        product_code|     month|gross_price|      read_timestamp|      file_name|file_size|
# +----------+--------------------+----------+-----------+--------------------+---------------+---------+
# |  25891101|e91ba9d665f90254d...|2025-07-01|       84.0|2026-01-15 22:28:...|gross_price.csv|     2741|
# |  25891101|e91ba9d665f90254d...|2025-08-01|        0.0|2026-01-15 22:28:...|gross_price.csv|     2741|
# |  25891101|e91ba9d665f90254d...|2025-09-01|       84.0|2026-01-15 22:28:...|gross_price.csv|     2741|
# |  25891101|e91ba9d665f90254d...|2025-10-01|       83.0|2026-01-15 22:28:...|gross_price.csv|     2741|
# |  25891101|e91ba9d665f90254d...|2025-11-01|       83.0|2026-01-15 22:28:...|gross_price.csv|     2741|
# +----------+--------------------+----------+-----------+--------------------+---------------+---------+
# only showing top 5 rows

# %%
df_joined.write\
 .format("delta") \
 .option("delta.enableChangeDataFeed", "true")\
 .option("mergeSchema", "true") \
 .mode("overwrite") \
 .saveAsTable(f"{catalog}.{silver_schema}.{data_source}")

# %% [markdown]
# ## Gold

# %%
df_silver = spark.sql(f"SELECT * FROM {catalog}.{silver_schema}.{data_source};")

# %%
# select only required columns
df_gold = df_silver.select("product_code", "month", "gross_price")
df_gold.show(5)
# Out:
# +--------------------+----------+-----------+
# |        product_code|     month|gross_price|
# +--------------------+----------+-----------+
# |e91ba9d665f90254d...|2025-07-01|       84.0|
# |e91ba9d665f90254d...|2025-08-01|        0.0|
# |e91ba9d665f90254d...|2025-09-01|       84.0|
# |e91ba9d665f90254d...|2025-10-01|       83.0|
# |e91ba9d665f90254d...|2025-11-01|       83.0|
# +--------------------+----------+-----------+
# only showing top 5 rows

# %%
df_gold.write\
 .format("delta") \
 .option("delta.enableChangeDataFeed", "true") \
 .mode("overwrite") \
 .saveAsTable(f"{catalog}.{gold_schema}.sb_dim_{data_source}")

# %% [markdown]
# ## Merging Data source with parent

# %%
df_gold_price = spark.table("fmcg.gold.sb_dim_gross_price")
df_gold_price.show(5)
# Out:
# +--------------------+----------+-----------+
# |        product_code|     month|gross_price|
# +--------------------+----------+-----------+
# |e91ba9d665f90254d...|2025-07-01|       84.0|
# |e91ba9d665f90254d...|2025-08-01|        0.0|
# |e91ba9d665f90254d...|2025-09-01|       84.0|
# |e91ba9d665f90254d...|2025-10-01|       83.0|
# |e91ba9d665f90254d...|2025-11-01|       83.0|
# +--------------------+----------+-----------+
# only showing top 5 rows

# %% [markdown]
# - Get the price for each product_code (aggregated by year)

# %%
df_gold_price = (
    df_gold_price
    .withColumn("year", F.year("month"))
    # 0 = non-zero price, 1 = zero price  ➜ non-zero comes first
    .withColumn("is_zero", F.when(F.col("gross_price") == 0, 1).otherwise(0))
)

w = (
    Window
    .partitionBy("product_code", "year")
    .orderBy(F.col("is_zero"), F.col("month").desc())
)


df_gold_latest_price = (
    df_gold_price
      .withColumn("rnk", F.row_number().over(w))
      .filter(F.col("rnk") == 1)
)

# %%
display(df_gold_latest_price)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>product_code</th><th>month</th><th>gross_price</th><th>year</th><th>is_zero</th><th>rnk</th></tr></thead><tbody><tr><td>062f5574bbdf4386b2c7c6075483b417b4a00b172fcba919dbba7dae1b774379</td><td>2025-12-01</td><td>281.0</td><td>2025</td><td>0</td><td>1</td></tr><tr><td>0cb7b2f42657b625f754e833aa1cf6a967be26f17415f5342302ebb0e90c8a28</td><td>2025-10-01</td><td>100.0</td><td>2025</td><td>0</td><td>1</td></tr><tr><td>102628255d24304d6bbe0438b1ac992054f262e0814d306d0a34d7356cef3268</td><td>2025-12-01</td><td>86.0</td><td>2025</td><td>0</td><td>1</td></tr><tr><td>2e387cef1424d6e7b162b45622d4b1a788d11776e33d05cc8552f4ecd2ea1896</td><td>2025-12-01</td><td>108.0</td><td>2025</td><td>0</td><td>1</td></tr><tr><td>3cab59f05924285270313afcfe40a08983bb03dd88f432e34fc6336914c14345</td><td>2025-12-01</td><td>493.0</td><td>2025</td><td>0</td><td>1</td></tr><tr><td>451f7167b28a25bde73995910e31c07dfa26411f1db47847f19e16747effbdaa</td><td>2025-12-01</td><td>187.0</td><td>2025</td><td>0</td><td>1</td></tr><tr><td>716fa4e54b7894c910180276e0535d49afb25cdcfac09533fb74ae00689e5742</td><td>2025-11-01</td><td>440.0</td><td>2025</td><td>0</td><td>1</td></tr><tr><td>778c2a7aa27bfdb211fd5ece048de80d00fbf3d6924bd908d91054796ba16ab6</td><td>2025-12-01</td><td>296.0</td><td>2025</td><td>0</td><td>1</td></tr><tr><td>77b6f538a9d0e0cf845db5c2cbecec46fdd30303b501e06f64baf1d4dc0e66f9</td><td>2025-12-01</td><td>50.0</td><td>2025</td><td>0</td><td>1</td></tr><tr><td>889c67757ece9c973791dfbc2d47b026a3342cc7255e47a3170329d158e897c2</td><td>2025-12-01</td><td>138.0</td><td>2025</td><td>0</td><td>1</td></tr><tr><td>c68834ceaff15846bc1892c2185dc4e4f471d64fe3796b1a8ecc39a5a48c614f</td><td>2025-12-01</td><td>432.0</td><td>2025</td><td>0</td><td>1</td></tr><tr><td>d9ebd1ca64d23951a6310af93b1c5ac27d831ac842e89aea59a9e8b38621faa5</td><td>2025-12-01</td><td>300.0</td><td>2025</td><td>0</td><td>1</td></tr><tr><td>da6bfc596c1360ca07bda4e0ae6bfe3b8456517fc6e8ddc265630ff940f9ab05</td><td>2025-12-01</td><td>79.0</td><td>2025</td><td>0</td><td>1</td></tr><tr><td>e91ba9d665f90254da5809bfdebe3db2be01a52f50b6fd96b57eed238392b843</td><td>2025-11-01</td><td>83.0</td><td>2025</td><td>0</td><td>1</td></tr><tr><td>e92c739a8d78cd6cbe954648c2f9dd75ed61fcfd99b03e10dca65c3082d0728e</td><td>2025-12-01</td><td>69.0</td><td>2025</td><td>0</td><td>1</td></tr><tr><td>ee1f7df9cf660ef02c33037d8d6eb94cbefe8e7b84c306e9387f09b0cae0abae</td><td>2025-12-01</td><td>365.0</td><td>2025</td><td>0</td><td>1</td></tr><tr><td>fe5a8036be4b9a787b7c0ae013fc752a8cfb6c55a2f7b2fd152a6380925e9c49</td><td>2025-11-01</td><td>53.0</td><td>2025</td><td>0</td><td>1</td></tr></tbody></table></div>

# %%
## Take required cols

df_gold_latest_price = df_gold_latest_price.select("product_code", "year", "gross_price").withColumnRenamed("gross_price", "price_dollars").select("product_code", "price_dollars", "year")

# change year to string
df_gold_latest_price = df_gold_latest_price.withColumn("year", F.col("year").cast("string"))

df_gold_latest_price.show(5)
# Out:
# +--------------------+-------------+----+
# |        product_code|price_dollars|year|
# +--------------------+-------------+----+
# |062f5574bbdf4386b...|        281.0|2025|
# |0cb7b2f42657b625f...|        100.0|2025|
# |102628255d24304d6...|         86.0|2025|
# |2e387cef1424d6e7b...|        108.0|2025|
# |3cab59f0592428527...|        493.0|2025|
# +--------------------+-------------+----+
# only showing top 5 rows

# %%
df_gold_latest_price.printSchema()
# Out:
# root
#  |-- product_code: string (nullable = true)
#  |-- price_dollars: double (nullable = true)
#  |-- year: string (nullable = true)

# %%
delta_table = DeltaTable.forName(spark, "fmcg.gold.dim_gross_price")


delta_table.alias("target").merge(
    source=df_gold_latest_price.alias("source"),
    condition="target.product_code = source.product_code"
).whenMatchedUpdate(
    set={
        "price_dollars": "source.price_dollars",
        "year": "source.year"
    }
).whenNotMatchedInsert(
    values={
        "product_code": "source.product_code",
        "price_dollars": "source.price_dollars",
        "year": "source.year"
    }
).execute()
# Out:
# DataFrame[num_affected_rows: bigint, num_updated_rows: bigint, num_deleted_rows: bigint, num_inserted_rows: bigint]
